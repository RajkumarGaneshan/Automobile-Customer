# %%
import os
import numpy as np
import pandas as pd
import random
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("D:/Kaagle Video games/Kaggle-3/train-set.csv")
data.head()
# Out:
#    CustomerID  Gender Married  Age Graduated     Profession  WorkExperience  \
# 0      462809    Male      No   22        No     Healthcare             1.0
# 1      462643  Female     Yes   38       Yes       Engineer             NaN
# 2      466315  Female     Yes   67       Yes       Engineer             1.0
# 3      461735    Male     Yes   67       Yes         Lawyer             0.0
# 4      462669  Female     Yes   40       Yes  Entertainment             NaN
#
#   SpendingScore  FamilySize    Category Segmentation
# 0           Low         4.0  Category 4            D
# 1       Average         3.0  Category 4            A
# 2           Low         1.0  Category 6            B
# 3          High         2.0  Category 6            B
# 4          High         6.0  Category 6            A

# %%
data.shape
# Out:
# (8068, 11)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8068 entries, 0 to 8067
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerID      8068 non-null   int64
#  1   Gender          8068 non-null   object
#  2   Married         7928 non-null   object
#  3   Age             8068 non-null   int64
#  4   Graduated       7990 non-null   object
#  5   Profession      7944 non-null   object
#  6   WorkExperience  7239 non-null   float64
#  7   SpendingScore   8068 non-null   object
#  8   FamilySize      7733 non-null   float64
#  9   Category        7992 non-null   object
#  10  Segmentation    8068 non-null   object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 693.5+ KB

# %%
data.isnull().sum()
# Out:
# CustomerID          0
# Gender              0
# Married           140
# Age                 0
# Graduated          78
# Profession        124
# WorkExperience    829
# SpendingScore       0
# FamilySize        335
# Category           76
# Segmentation        0
# dtype: int64

# %%
data.drop(['CustomerID'],axis=1,inplace=True)

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %%
numerical=data.select_dtypes(include=np.number)
print(len(numerical.columns))
numerical.columns
# Out:
# 3
# Index(['Age', 'WorkExperience', 'FamilySize'], dtype='object')

# %%
categorical=data.select_dtypes(include=object)
print(len(categorical.columns))
categorical.columns
# Out:
# 7
# Index(['Gender', 'Married', 'Graduated', 'Profession', 'SpendingScore',
#        'Category', 'Segmentation'],
#       dtype='object')

# %% [markdown]
# # Missing_values_treating and Data_Visualization

# %%
data.Gender.value_counts()
# Out:
# Male      4417
# Female    3651
# Name: Gender, dtype: int64

# %%
sns.countplot(data.Gender)
plt.show()

# %%
data.Married.value_counts()
# Out:
# Yes    4643
# No     3285
# Name: Married, dtype: int64

# %%
data['Married'] = data['Married'].fillna(data['Married'].mode()[0])

# %%
data.Age.value_counts()
# Out:
# 35    250
# 37    234
# 42    232
# 33    232
# 40    229
#      ...
# 78     29
# 87     28
# 76     27
# 80     24
# 85     22
# Name: Age, Length: 67, dtype: int64

# %%
plt.hist(data.Age,bins='auto')
plt.show()

# %%
sns.distplot(data.Age)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
props=dict(boxes='yellow',whiskers='green',medians='black',caps='red')
data.Age.plot.box(patch_artist=True,vert=False,color=props)
plt.show()

# %%
iqr=data.Age.describe()['75%']-data.Age.describe()['25%']

# %%
ul=data.Age.describe()['75%']+1.5*iqr

# %%
print(ul)
# Out:
# 87.5

# %%
data=data[data.Age>=ul]

# %%
data.Graduated.value_counts()
# Out:
# Yes    43
# No     27
# Name: Graduated, dtype: int64

# %%
sns.countplot(data.Graduated)
plt.show()

# %%
data['Graduated'] = data['Graduated'].fillna(data['Graduated'].mode()[0])

# %%
data.Profession.value_counts()
# Out:
# Lawyer           53
# Executive         7
# Artist            6
# Marketing         2
# Entertainment     1
# Doctor            1
# Name: Profession, dtype: int64

# %%
sns.countplot(data.Profession)
# Out:
# <AxesSubplot:xlabel='Profession', ylabel='count'>

# %%
data['Profession'] = data['Profession'].fillna(data['Profession'].mode()[0])

# %%
data.WorkExperience.value_counts()
# Out:
# 0.0     27
# 1.0     26
# 3.0      3
# 2.0      2
# 13.0     1
# 7.0      1
# 6.0      1
# Name: WorkExperience, dtype: int64

# %%
plt.hist(data.WorkExperience,bins='auto')
plt.show()

# %%
props=dict(boxes='yellow',whiskers='green',medians='black',caps='red')
data.WorkExperience.plot.box(patch_artist=True,vert=False,color=props)
plt.show()

# %%
iqr=data.WorkExperience.describe()['75%']-data.WorkExperience.describe()['25%']

# %%
ul=data.WorkExperience.describe()['75%']+1.5*iqr

# %%
ul
# Out:
# 2.5

# %%
data=data[data['WorkExperience'] <= ul]

# %%
data['WorkExperience'] = data['WorkExperience'].fillna(data['WorkExperience'].median())

# %%
data.SpendingScore.value_counts()
# Out:
# High       35
# Low        19
# Average     1
# Name: SpendingScore, dtype: int64

# %%
sns.countplot(data.SpendingScore)
# Out:
# <AxesSubplot:xlabel='SpendingScore', ylabel='count'>

# %%
data.FamilySize.value_counts()
# Out:
# 2.0    32
# 1.0    12
# 3.0     6
# Name: FamilySize, dtype: int64

# %%
plt.hist(data.FamilySize)
# Out:
# (array([12.,  0.,  0.,  0.,  0., 32.,  0.,  0.,  0.,  6.]),
#  array([1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4, 2.6, 2.8, 3. ]),
#  <BarContainer object of 10 artists>)

# %%
props=dict(boxes='yellow',whiskers='green',medians='black',caps='red')
data.FamilySize.plot.box(patch_artist=True,vert=False,color=props)
plt.show()

# %%
data['FamilySize']=data['FamilySize'].fillna(data['FamilySize'].median())

# %%
iqr=data['FamilySize'].quantile(0.75) - data['FamilySize'].quantile(0.25)
iqr
# Out:
# 0.0

# %%
ul=data['FamilySize'].quantile(0.75) + (1.5*iqr)
ul
# Out:
# 2.0

# %%
data=data[data['FamilySize'] <= ul]

# %%
data.Category.value_counts()
# Out:
# Category 6    46
# Category 4     1
# Category 2     1
# Name: Category, dtype: int64

# %%
sns.countplot(data.Category)
# Out:
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %%
data['Category'] = data['Category'].fillna(data['Category'].mode()[0])

# %%
data.Segmentation.value_counts()
# Out:
# A    19
# C    12
# D     9
# B     9
# Name: Segmentation, dtype: int64

# %%
sns.countplot(data.Segmentation)
# Out:
# <AxesSubplot:xlabel='Segmentation', ylabel='count'>

# %%
data.isnull().sum()
# Out:
# Gender            0
# Married           0
# Age               0
# Graduated         0
# Profession        0
# WorkExperience    0
# SpendingScore     0
# FamilySize        0
# Category          0
# Segmentation      0
# dtype: int64

# %%
from scipy.stats import chi2_contingency

# %%
for i in categorical:
    a=pd.crosstab(index=data[i],columns=data['Segmentation'])
    print(a)
    b=chi2_contingency(a)
    print('p value is:',b[1])
    if b[1]<0.05:
        print('It is a good predictor')
    else:
        print('Bad Predictor')
    print('\n')
# Out:
# Segmentation   A  B  C  D
# Gender
# Female         8  6  8  6
# Male          11  3  4  3
# p value is: 0.41283111280316576
# Bad Predictor
#
#
# Segmentation   A  B   C  D
# Married
# No             1  0   0  1
# Yes           18  9  12  8
# p value is: 0.5524591873530016
# Bad Predictor
#
#
# Segmentation   A  B   C  D
# Graduated
# No            10  5   0  3
# Yes            9  4  12  6
# p value is: 0.015101620751866591
# It is a good predictor
#
#
# Segmentation   A  B  C  D
# Profession
# Artist         1  0  3  0
# Executive      2  0  0  1
# Lawyer        16  9  7  8
# Marketing      0  0  2  0
# p value is: 0.0781874872492647
# Bad Predictor
#
#
# Segmentation    A  B   C  D
# SpendingScore
# Average         0  0   1  0
# High           10  7  10  2
# Low             9  2   1  7
# p value is: 0.025440502348836727
# It is a good predictor
#
#
# Segmentation   A  B   C  D
# Category
# Category 2     0  0   1  0
# Category 4     1  0   0  0
# Category 6    18  9  11  9
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
for i in categorical:
    label=LabelEncoder()
    data[i]=label.fit_transform(data[i])

# %%
data.head()
# Out:
#       Gender  Married  Age  Graduated  Profession  WorkExperience  \
# 699        1        1   88          0           1             0.0
# 753        0        1   88          0           2             0.0
# 1108       0        1   89          1           2             0.0
# 1179       0        1   88          1           2             1.0
# 1213       0        1   89          0           2             0.0
#
#       SpendingScore  FamilySize  Category  Segmentation
# 699               2         1.0         2             0
# 753               1         2.0         2             1
# 1108              1         2.0         2             2
# 1179              2         1.0         2             3
# 1213              1         2.0         2             1

# %%
data.drop(['Age'],axis=1,inplace=True)

# %%
data.head()
# Out:
#       Gender  Married  Graduated  Profession  WorkExperience  SpendingScore  \
# 699        1        1          0           1             0.0              2
# 753        0        1          0           2             0.0              1
# 1108       0        1          1           2             0.0              1
# 1179       0        1          1           2             1.0              2
# 1213       0        1          0           2             0.0              1
#
#       FamilySize  Category  Segmentation
# 699          1.0         2             0
# 753          2.0         2             1
# 1108         2.0         2             2
# 1179         1.0         2             3
# 1213         2.0         2             1

# %%
#ibrary for VIF
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
data.isnull().sum()
# Out:
# Gender            0
# Married           0
# Graduated         0
# Profession        0
# WorkExperience    0
# SpendingScore     0
# FamilySize        0
# Category          0
# Segmentation      0
# dtype: int64

# %%
def calculate_vif(dataset):
    vif = pd.DataFrame()
    vif["features"] = dataset.columns
    vif["VIF_Values"] = [variance_inflation_factor(dataset.values, i) for i in range(dataset.shape[1])]
    return(vif)

# %%
features = data.iloc[:,:-1]
calculate_vif(features)
# Out:
#          features  VIF_Values
# 0          Gender    2.048577
# 1         Married   23.390072
# 2       Graduated    2.915492
# 3      Profession    9.951928
# 4  WorkExperience    2.255288
# 5   SpendingScore   10.479740
# 6      FamilySize   18.601855
# 7        Category   31.222971

# %%
plt.figure(figsize=(18,15),dpi=150)
sns.heatmap(data.corr(),annot=True,cmap='YlGnBu',lw=0.2,annot_kws={'size':20})
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %%
x=data.drop(['Segmentation'],axis=1)
y=data['Segmentation']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25, random_state=25)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,confusion_matrix

# %%
log_reg = LogisticRegression()
log_reg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
log_acc=accuracy_score(y_test,log_reg.predict(x_test))

# %%
print("Train Set Accuracy:"+str(accuracy_score(y_train,log_reg.predict(x_train))*100))
print("Test Set Accuracy:"+str(accuracy_score(y_test,log_reg.predict(x_test))*100))
# Out:
# Train Set Accuracy:55.55555555555556
# Test Set Accuracy:23.076923076923077

# %%
confusion_matrix(y_test,log_reg.predict(x_test))
# Out:
# array([[2, 0, 1, 0],
#        [2, 0, 0, 0],
#        [3, 1, 1, 0],
#        [3, 0, 0, 0]], dtype=int64)

# %%
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score,roc_curve,auc,roc_auc_score

# %%
y_pred= log_reg.predict(x_test)
#fpr_keras, tpr_keras, thresholds_keras = roc_curve(y_test, y_pred)

# %%
y_pred
# Out:
# array([0, 0, 2, 0, 0, 0, 0, 0, 2, 0, 0, 1, 0])

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 0.23076923076923078

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.12, random_state=25)

# %%
from sklearn import tree

# %%
clf=tree.DecisionTreeClassifier()
clffit=clf.fit(x_train,y_train)
print(clffit)
# Out:
# DecisionTreeClassifier()

# %%
y_pred1=clffit.predict(x_test)
y_pred1
# Out:
# array([0, 3, 2, 0, 2, 0])

# %%
print(accuracy_score(y_test,y_pred1))
# Out:
# 0.6666666666666666

# %%
print(confusion_matrix(y_test,y_pred1))
# Out:
# [[1 0 0]
#  [1 2 0]
#  [1 0 1]]

# %%
print(classification_report(y_test,y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.33      1.00      0.50         1
#            2       1.00      0.67      0.80         3
#            3       1.00      0.50      0.67         2
#
#     accuracy                           0.67         6
#    macro avg       0.78      0.72      0.66         6
# weighted avg       0.89      0.67      0.71         6
